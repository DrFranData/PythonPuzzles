# %% [markdown]
# <a href="https://colab.research.google.com/github/DrFranData/PythonPuzzles/blob/main/8_Column_Indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🧩 Puzzle 8: "Column indexing"
#
# ####📖 Concepts You Need:
# **Pandas DataFrames**: Creating a simple DataFrame.
#
# **Indexing**: Selecting a specific column.
# ###💡 Puzzle:
# Write a Python program that creates a simple DataFrame with names and ages, then prints only the "Age" column.
#
# ###🖥 Example Output:
# ```
# Ages of people:
# 0    25
# 1    30
# 2    22
# 3    40
# Name: Age, dtype: int64
# ```
