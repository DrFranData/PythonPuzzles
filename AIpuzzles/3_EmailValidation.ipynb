# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DrFranData/PythonPuzzles/blob/main/AIpizzles/3_EmailValidation.ipynb)
# <div style="border: 2px solid #1976d2; border-radius: 5px; padding: 10px; background-color: #e3f2fd;">
#     <h2 style="color: #0d47a1;">📊 AI-Enhanced Puzzle: Clean and Validate Emails</h2>
#     <p style="font-size: 16px;">Welcome to a real-world Python + AI challenge! In this puzzle, you’ll use regular expressions to identify and clean invalid email addresses from a dataset. Then, try prompting an AI assistant to optimize or explain your solution. This puzzle belongs to <strong>Phase 3: AI-Enhanced Applications</strong>.</p>
#     <p style="font-size: 16px; color: #1565c0;"><strong>Goal:</strong> Strengthen your ability to combine Python skills with critical AI use.</p>
# </div>

# %% [markdown]
# ### Puzzle: Remove Invalid Email Addresses
# Given a list of email addresses, write a function that returns only those that are valid.
# A valid email:
# - contains exactly one '@' symbol
# - ends with a common domain (e.g., '.com', '.org', '.net')
# - contains no spaces

# %%
import re

def clean_emails(email_list):
    # Your code here
    pass

# Example input
emails = [
    'user@example.com',
    'invalid@ email.com',
    'another.user@site.org',
    'bademail.com',
    'good.email@domain.net',
    'noatsymbol.com'
]

print(clean_emails(emails))
# Expected output: ['user@example.com', 'another.user@site.org', 'good.email@domain.net']

# %% [markdown]
# ### Suggested Prompts for AI Assistance
# - "Can you help me write a regex that validates email addresses in Python?"
# - "Explain why a regex might fail to catch certain email formatting errors."
# - "What are some limitations of using regex for email validation?"
# - "Can you suggest a Pythonic alternative if I don't want to use regex?"
# - "Optimize this function for larger datasets."
# - "What’s the time complexity of my solution?"
# - "How can I make this code more readable for team collaboration?"
#
# ### Reflective Questions
# - How confident are you in the regex pattern used—did you verify its accuracy?
# - Did the AI solution match your expectations? Why or why not?
# - How would you explain the risks of over-relying on AI-generated code to a peer?
# - What steps did you take to ensure the AI-generated suggestions were correct and safe?

# %% [markdown]
# <details>
#   <summary><b>Show Solution</b></summary>
#
# ```python
# import re
#
# def clean_emails(email_list):
#     pattern = re.compile(r'^[^\s@]+@[^\s@]+\.(com|org|net)$')
#     return [email for email in email_list if pattern.match(email)]
# ```
#
# </details>
