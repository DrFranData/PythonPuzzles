# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github//DrFranData/PythonPuzzles/blob/main/AIpuzzles/ExtractLinks.ipynb)
# <div style="border: 2px solid #2196F3; border-radius: 5px; padding: 10px; background-color: #e3f2fd;">
#     <h2 style="color: #0d47a1;">🔍 Phase 3 Puzzle – Real-World Application</h2>
#     <p style="font-size: 16px;">In this challenge, you're applying your Python skills to a practical data extraction task. You'll use HTML parsing to automate hyperlink collection — a common step in web scraping or report generation.</p>
# </div>

# %% [markdown]
# ### Puzzle: Extract All Hyperlinks from an HTML Page
# Write a function `extract_links(html)` that takes a string of HTML and returns a list of all the URLs (i.e., values from `href` attributes inside `<a>` tags).
#
# Use libraries like `BeautifulSoup` from `bs4` for parsing.
#
# **Example Input:**
# ```html
# <html><body><a href='https://example.com'>Example</a><a href='https://openai.com'>OpenAI</a></body></html>
# ```
#
# **Expected Output:**
# ```python
# ["https://example.com", "https://openai.com"]
# ```

# %%
from bs4 import BeautifulSoup

def extract_links(html):
    # Your code here
    return []

# %%
# Test your function
html = "<html><body><a href='https://example.com'>Example</a><a href='https://openai.com'>OpenAI</a></body></html>"
print(extract_links(html))  # Expected output: ['https://example.com', 'https://openai.com']

# %% [markdown]
# <details>
#   <summary><b>Show Solution</b></summary>
#
# ```python
# from bs4 import BeautifulSoup
#
# def extract_links(html):
#     soup = BeautifulSoup(html, 'html.parser')
#     return [a['href'] for a in soup.find_all('a', href=True)]
# ```
# </details>

# %% [markdown]
# ### 🤖 Suggested AI Prompts (Phase 3 – AI as a Coding Collaborator)
#
# - "Can you help me extract all the `href` values from `<a>` tags in this HTML?"
# - "Is BeautifulSoup the best tool for this task? What alternatives exist?"
# - "How do I handle malformed or missing href attributes safely?"
# - "Can you generate test cases for edge cases, like empty `href` or nested tags?"
# - "What’s the difference between `soup.find_all('a')` and `soup.select()`?"
# - "How can I filter for only `https` links in the output?"
# - "Could I turn this into a command-line tool or script that processes a local HTML file?"

# %% [markdown]
# ### 🧠 Reflective Questions
#
# - What would change if this input was a full web page from a live URL?
# - Did AI give a working solution right away? What did you have to adjust?
# - How confident are you in explaining the final code to someone else?
# - What are some ethical considerations when using code to scrape the web?
