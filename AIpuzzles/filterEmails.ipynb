# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DrFranData/PythonPuzzles/blob/main/AIpuzzles/filterEmails.ipynb)
# <div style="border: 2px solid #4CAF50; border-radius: 5px; padding: 10px; background-color: #e8f5e9;">
#     <h2 style="color: #2e7d32;">🧩 Python Puzzle Time! (Phase 3)</h2>
#     <p style="font-size: 16px;">Welcome to today's Python challenge! 🐍 In this puzzle, you'll be working with <strong>Python code snippets</strong> where you need to either <strong>fill in the blanks</strong> or <strong>guess the output</strong>. This is a fun way to test and sharpen your Python skills. Ready to dive in and solve it?</p>
#     <p style="font-size: 16px; color: #388e3c;"><strong>Give it your best shot!</strong></p>
# </div>

# %% [markdown]
# ### Puzzle: Filter Emails
# Write a function `filter_gmail(users)` that returns only Gmail addresses from a list of email addresses.

# %%
def filter_gmail(users):
    # Your code here

# %%
print(filter_gmail(['a@gmail.com', 'b@yahoo.com'])) # expected: ['a@gmail.com']

# %% [markdown]
# <details>
#   <summary><b>Show Solution</b></summary>
# ```python
# def filter_gmail(users):
#     return [email for email in users if email.endswith('@gmail.com')]
# ```
# </details>
